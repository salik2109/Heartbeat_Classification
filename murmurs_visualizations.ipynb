# %%
import warnings
warnings.filterwarnings("ignore")
import os
import pandas as pd
import librosa
import librosa.display
import glob
import tensorflow as tf
import keras
import os
import fnmatch
import matplotlib.pyplot as plt
from os.path import isfile
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, LSTM
from keras.layers import Conv1D, MaxPool1D, GlobalAvgPool1D, Dropout, BatchNormalization, Dense
from keras.regularizers import l2
from keras.layers import Convolution2D, MaxPooling2D
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping,ReduceLROnPlateau,ModelCheckpoint,TensorBoard,ProgbarLogger
from keras.utils import np_utils
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder
import itertools

# %%
SR = 16000
INPUT_DIR = "heartbeat-sounds/"
PSM = INPUT_DIR + 'PSM/'
ESM = INPUT_DIR + 'ESM/'

# %%
X, sr1 = librosa.load(PSM+'2.wav', duration=4.0, res_type='kaiser_fast')
mfccs1 = np.mean(librosa.feature.mfcc(y=X, sr=SR, n_mfcc=40).T, axis=0)
print(mfccs1.shape)
print(sr1,len(X))
# Out:
# (40,)
# 22050 88200

# %%
# plt.figure()
# librosa.display.plot(X)
plt.plot(mfccs)

# %%
Y, sr2 = librosa.load(ESM+'10.wav', duration=4.0, res_type='kaiser_fast')
mfccs2 = np.mean(librosa.feature.mfcc(y=Y, sr=SR, n_mfcc=40).T, axis=0)
print(mfccs2.shape)
print(sr2, len(Y))
# Out:
# (40,)
# 22050 71928

# %%
# plt.figure()
# librosa.display.waveplot(Y)
plt.plot(mfccs1, 'r')
plt.plot(mfccs2,'b')
